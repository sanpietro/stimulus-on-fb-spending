# 39    May  2018    drink   2.00    3    6.00
# 40    May  2018  dessert   3.00    1    3.00
# 23    Mar  2018  dessert   1.75    2    3.50
# 3     Jan  2018     food   2.75    5   13.75
# 31    Apr  2018  dessert   2.25    2    4.50
# 47    Jun  2018     food   5.50    2   11.00
# 48    Jun  2018    drink   2.50    2    5.00
# 49    Jun  2018  dessert   3.50    0    0.00
# 30    Apr  2018    drink   1.25    4    5.00
# 103   Dec  2018  dessert   1.00    3    3.00
# 101   Dec  2018     food   3.00    5   15.00
# 104   Dec  2019     food   3.00    5   15.00
# 7     Jan  2019    drink  -0.25    6   -1.50
# 8     Jan  2019  dessert   0.75    4    3.00
# 88    Oct  2019  dessert   1.75    3    5.25
# 6     Jan  2019     food   2.75    5   13.75
# 97    Nov  2019  dessert   1.50    4    6.00
# 96    Nov  2019    drink   0.50    6    3.00
# 95    Nov  2019     food   3.50    5   17.50
# 86    Oct  2019     food   3.75    5   18.75
# 87    Oct  2019    drink   0.75    5    3.75
# 25    Mar  2019    drink   0.75    5    3.75
# 78    Sep  2019    drink   1.00    4    4.00
# 24    Mar  2019     food   3.75    4   15.00
# 32    Apr  2019     food   4.25    4   17.00
# 33    APR  2019    drink   1.25    5    6.25
# 34    Apr  2019  dessert   2.25    3    6.75
# 41    May  2019     food   5.00    3   15.00
# 42    May  2019    drink   2.00    4    8.00
# 43    May  2019  dessert   3.00    2    6.00
# 50    Jun  2019     food   5.50    3   16.50
# 51    Jun  2019    drink   2.50    4   10.00
# 52    Jun  2019  dessert   3.50    1    3.50
# 79    Sep  2019  dessert   2.00    2    4.00
# 105   Dec  2019    drink   0.00    6    0.00
# 16    Feb  2019    drink   0.25    6    1.50
# 59    Jul  2019     food   5.25    2   10.50
# 60    Jul  2019    drink   2.25    2    4.50
# 61    Jul  2019  dessert   3.25    0    0.00
# 15    Feb  2019     food   3.25    5   16.25
# 26    Mar  2019  dessert   1.75    3    5.25
# 68    Aug  2019     food   5.00    3   15.00
# 69    Aug  2019    drink   2.00    4    8.00
# 70    Aug  2019  dessert   3.00    1    3.00
# 77    Sep  2019     food   4.00    4   16.00
# 17    Feb  2019  dessert   1.25    3    3.75
# 106   Dec  2019  dessert   1.00    4    4.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 0 to 106
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   month     107 non-null    object
#  1   year      107 non-null    int64
#  2   category  107 non-null    object
#  3   price     107 non-null    float64
#  4   qty       107 non-null    int64
#  5   amount    107 non-null    float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 5.9+ KB

# %% [markdown]
# ## Scrubbing

# %%
#Check for NULLs
df.isna().sum()
# Out:
# month       0
# year        0
# category    0
# price       0
# qty         0
# amount      0
# dtype: int64

# %%
##Convert objects to category
for col in df:
    if df[col].dtype == "object":
       df[col] = df[col].astype('category')
    print(df[col].dtype)
# Out:
# category
# int64
# category
# float64
# int64
# float64

# %%
# Deal with dates
l= []

import calendar

for d in df.month:
    d=d.title()
    print(d)
    r=calendar.month_name [list(calendar.month_abbr).index(d)]
    print(r)
    l.append(r)
    
df['month']= l
df
# Out:
# Jan
# January
# Jan
# January
# Jan
# January
# Jan
# January
# 69  2019-08-01     August  2019    drink   2.00    4    8.00
# 79  2019-09-01  September  2019  dessert   2.00    2    4.00
# 77  2019-09-01  September  2019     food   4.00    4   16.00
# 78  2019-09-01  September  2019    drink   1.00    4    4.00
# 88  2019-10-01    October  2019  dessert   1.75    3    5.25
# 87  2019-10-01    October  2019    drink   0.75    5    3.75
# 86  2019-10-01    October  2019     food   3.75    5   18.75
# 95  2019-11-01   November  2019     food   3.50    5   17.50
# 97  2019-11-01   November  2019  dessert   1.50    4    6.00
# 96  2019-11-01   November  2019    drink   0.50    6    3.00
# 104 2019-12-01   December  2019     food   3.00    5   15.00
# 105 2019-12-01   December  2019    drink   0.00    6    0.00
# 106 2019-12-01   December  2019  dessert   1.00    4    4.00

# %%
# Check for unique characters

for col in list(df):
    print(col)
    print(df[col].unique())
# Out:
# date
# ['2017-01-01T00:00:00.000000000' '2017-02-01T00:00:00.000000000'
#  '2017-03-01T00:00:00.000000000' '2017-04-01T00:00:00.000000000'
#  '2017-05-01T00:00:00.000000000' '2017-06-01T00:00:00.000000000'
#  '2017-07-01T00:00:00.000000000' '2017-08-01T00:00:00.000000000'
#  '2017-09-01T00:00:00.000000000' '2017-10-01T00:00:00.000000000'
#  '2017-11-01T00:00:00.000000000' '2017-12-01T00:00:00.000000000'
#  '2018-01-01T00:00:00.000000000' '2018-02-01T00:00:00.000000000'
#  '2018-03-01T00:00:00.000000000' '2018-04-01T00:00:00.000000000'
#  '2018-05-01T00:00:00.000000000' '2018-06-01T00:00:00.000000000'
#  '2018-07-01T00:00:00.000000000' '2018-08-01T00:00:00.000000000'
#  '2018-09-01T00:00:00.000000000' '2018-10-01T00:00:00.000000000'
#  '2018-11-01T00:00:00.000000000' '2018-12-01T00:00:00.000000000'
#  '2019-01-01T00:00:00.000000000' '2019-02-01T00:00:00.000000000'
#  '2019-03-01T00:00:00.000000000' '2019-04-01T00:00:00.000000000'
#  '2019-05-01T00:00:00.000000000' '2019-06-01T00:00:00.000000000'
#  '2019-07-01T00:00:00.000000000' '2019-08-01T00:00:00.000000000'
#  '2019-09-01T00:00:00.000000000' '2019-10-01T00:00:00.000000000'
#  '2019-11-01T00:00:00.000000000' '2019-12-01T00:00:00.000000000']
# month
# ['January' 'February' 'March' 'April' 'May' 'June' 'July' 'August'
#  'September' 'October' 'November' 'December']
# year
# [2017 2018 2019]
# category
# [food, drink, dessert, 1059]
# Categories (4, object): [food, drink, dessert, 1059]
# price
# [ 2.75 -0.25  0.75  1.25  0.25  3.25  3.75  1.75  2.25  4.25  3.    2.
#   5.    2.5   5.5   3.5   5.25  4.    1.    0.5   1.5   0.  ]
# qty
# [4 2 3 1 0 5 6]
# amount
# [11.   -1.    1.5   2.5   1.   13.   11.25  1.75  2.25  3.75 12.75  3.
#   6.   10.    5.    0.    5.25  4.    8.   15.    3.5  14.    2.   12.
#  -1.25 13.75  1.25 16.25  4.5  -1.5  17.    6.75  6.25 16.5  10.5  16.
#  18.75 17.5 ]

# %%
# Remove unique characters

df[df['category']=='1059'].count()
# Out:
# date        1
# month       1
# year        1
# category    1
# price       1
# qty         1
# amount      1
# dtype: int64

# %%
df[df['category']==1059].count()
# Out:
# date        0
# month       0
# year        0
# category    0
# price       0
# qty         0
# amount      0
# dtype: int64

# %%
df=df[df['category']!='1059']

# %%
df[df['category']=='1059'].count()
# Out:
# date        0
# month       0
# year        0
# category    0
# price       0
# qty         0
# amount      0
# dtype: int64

# %%
df=df[df['amount']>0]
df[df['amount']<0].count()
# Out:
# date        0
# month       0
# year        0
# category    0
# price       0
# qty         0
# amount      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94 entries, 0 to 106
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      94 non-null     datetime64[ns]
#  1   month     94 non-null     object
#  2   year      94 non-null     int64
#  3   category  94 non-null     category
#  4   price     94 non-null     float64
#  5   qty       94 non-null     int64
#  6   amount    94 non-null     float64
# dtypes: category(1), datetime64[ns](1), float64(2), int64(2), object(1)
# memory usage: 5.4+ KB

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Total Amounts
#
# **Overall, spending cratered during the Summer, but something happened that caused overall sales**
# **to increase significanty in 2019**

# %%
dft=df.copy()
dft = dft.groupby(['date']).sum()['amount']
dft.plot(figsize=(10,5));

# %%
dft=dft.reset_index()

# %% [markdown]
# ### Food purchases by month

# %%
dff=df.copy()

dff = dff[dff['category']=='food'].groupby(['date']).agg({'amount':sum})
dff.plot(figsize=(10,5));

# %%
dff=dff.reset_index()
dff.head()
# Out:
#         date  amount
# 0 2017-01-01   11.00
# 1 2017-02-01   13.00
# 2 2017-03-01   11.25
# 3 2017-04-01   12.75
# 4 2017-05-01   10.00

# %% [markdown]
# ### Drink purchases by month

# %%
dfdr=df.copy()

dfdr = dfdr[dfdr['category']=='drink'].groupby(['date']).agg({'amount':sum}) 

dfdr.plot(figsize=(10,5));

# %%
dfdr=dfdr.reset_index()
dfdr.head()
# Out:
#         date  amount
# 0 2017-02-01    1.00
# 1 2017-03-01    2.25
# 2 2017-04-01    3.75
# 3 2017-05-01    6.00
# 4 2017-06-01    5.00

# %% [markdown]
# ### Dessert purchases by month
#
# **It's noteworthy that dessert sales start to fall off as the weather gets cold (probably ice cream sales)**

# %%
dfdes=df.copy()

dfdes = dfdes[dfdes['category']=='dessert'].groupby(['date']).agg({'amount':sum}) 

dfdes.plot(figsize=(10,5));

# %%
dfdes.reset_index(inplace=True)
dfdes
# Out:
#          date  amount
# 0  2017-01-01    1.50
# 1  2017-02-01    2.50
# 2  2017-03-01    1.75
# 3  2017-04-01    2.25
# 4  2017-05-01    3.00
# 5  2017-10-01    3.50
# 6  2017-11-01    3.00
# 7  2017-12-01    2.00
# 8  2018-01-01    2.25
# 9  2018-02-01    3.75
# 10 2018-03-01    3.50
# 11 2018-04-01    4.50
# 12 2018-05-01    3.00
# 13 2018-08-01    3.00
# 14 2018-09-01    2.00
# 15 2018-10-01    3.50
# 16 2018-11-01    4.50
# 17 2018-12-01    3.00
# 18 2019-01-01    3.00
# 19 2019-02-01    3.75
# 20 2019-03-01    5.25
# 21 2019-04-01    6.75
# 22 2019-05-01    6.00
# 23 2019-06-01    3.50
# 24 2019-08-01    3.00
# 25 2019-09-01    4.00
# 26 2019-10-01    5.25
# 27 2019-11-01    6.00
# 28 2019-12-01    4.00

# %% [markdown]
# ### A check for multicollinearity

# %%
plt.figure(figsize=(15, 12))
sns.heatmap(df[['price','qty','amount']].corr(), annot=True)

# %% [markdown]
# ### Data distribution assessment and outlier check

# %%
df[['price','qty','amount']].hist(figsize = (40,20));

# %%
(df['price'] > 5).sum()
df[df['price']>5]
# Out:
#          date month  year category  price  qty  amount
# 44 2017-06-01  June  2017     food   5.50    2   11.00
# 53 2017-07-01  July  2017     food   5.25    1    5.25
# 47 2018-06-01  June  2018     food   5.50    2   11.00
# 56 2018-07-01  July  2018     food   5.25    1    5.25
# 50 2019-06-01  June  2019     food   5.50    3   16.50
# 59 2019-07-01  July  2019     food   5.25    2   10.50

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 94 entries, 0 to 106
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      94 non-null     datetime64[ns]
#  1   month     94 non-null     object
#  2   year      94 non-null     int64
#  3   category  94 non-null     category
#  4   price     94 non-null     float64
#  5   qty       94 non-null     int64
#  6   amount    94 non-null     float64
# dtypes: category(1), datetime64[ns](1), float64(2), int64(2), object(1)
# memory usage: 5.4+ KB

# %%
df = df[df['price']<=5]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 88 entries, 0 to 106
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      88 non-null     datetime64[ns]
#  1   month     88 non-null     object
#  2   year      88 non-null     int64
#  3   category  88 non-null     category
#  4   price     88 non-null     float64
#  5   qty       88 non-null     int64
#  6   amount    88 non-null     float64
# dtypes: category(1), datetime64[ns](1), float64(2), int64(2), object(1)
# memory usage: 5.1+ KB

# %%
df.price.hist()

# %% [markdown]
# ## Model a 12-month forecast for Total, Food, Drink & Dessert (Using FB Prophet)

# %%
from fbprophet import Prophet
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
d=[dft,dff,dfdr,dfdes]

for i in d:
    i.rename(columns = {'date':'ds','amount':'y'}, inplace = True)

# %%
l1=[]
for i in d:
          
    m = Prophet()
    m.fit(i)
    future = m.make_future_dataframe(periods=12, freq='M')
    forecast = m.predict(future)
    l1.append(forecast)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 23.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 22.

# %%
dftfcst = l1[0]
dfffcst = l1[1]
dfdrfcst = l1[2]
dfdesfcst = l1[3]

# %%
fig = m.plot(dftfcst)

# %% [markdown]
# ### Fairly good R^2, but does not reflect COVID spending changes

# %%
metric_df = dftfcst.set_index('ds')[['yhat']].join(dft.set_index('ds').y).reset_index()

metric_df.dropna(inplace=True)

r2_score(metric_df.y, metric_df.yhat)
# Out:
# 0.7980442727984209

# %% [markdown]
# ## Next, we take each category, model the forecast to get 2020 values,
# ## adjust the values to account for stimulus spending beginning in April,
# ## and re-run the models to forecast 2021 months

# %% [markdown]
# ## Food

# %%
dfffcst = dfffcst[['ds','yhat']]

# %%
dfffcst.head()
# Out:
#           ds       yhat
# 0 2017-01-01  10.763956
# 1 2017-02-01  12.761875
# 2 2017-03-01  11.341520
# 3 2017-04-01  12.667073
# 4 2017-05-01  11.149142

# %%
from datetime import timedelta, date
start=dfffcst[(dfffcst['ds']>"2020-04-01") & (dfffcst['ds']<"2020-12-01")]
adj=dfffcst[(dfffcst['ds']<"2020-04-01") & (dfffcst['ds']>="2017-01-01")]

# %%
# We model a 10% increase in food sales beginning in April

for d in start.ds:
    start['adjfcst']=(start['yhat']*1.1)

for x in adj.ds:
    adj['adjfcst']=(adj['yhat'])
# Out:
# /Users/joesanpietro/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/joesanpietro/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
foodfcst=pd.concat([start, adj])

foodfcst.sort_values(by='ds')
# Out:
#            ds       yhat    adjfcst
# 0  2017-01-01  10.763956  10.763956
# 1  2017-02-01  12.761875  12.761875
# 2  2017-03-01  11.341520  11.341520
# 3  2017-04-01  12.667073  12.667073
# 4  2017-05-01  11.149142  11.149142
# 5  2017-06-01  10.702396  10.702396
# 6  2017-07-01   5.106218   5.106218
# 7  2017-08-01   9.814280   9.814280
# 8  2017-09-01   8.457475   8.457475
# 9  2017-10-01  14.506269  14.506269
# 10 2017-11-01  13.169521  13.169521
# 11 2017-12-01  11.960410  11.960410
# 12 2018-01-01  12.829254  12.829254
# 13 2018-02-01  15.163520  15.163520
# 14 2018-03-01  13.753307  13.753307
# 15 2018-05-01  13.335882  13.335882
# 16 2018-06-01  12.835277  12.835277
# 17 2018-07-01   6.996464   6.996464
# 18 2018-08-01  11.657026  11.657026
# 19 2018-09-01  11.997006  11.997006
# 20 2018-10-01  16.253993  16.253993
# 21 2018-11-01  15.164024  15.164024
# 22 2018-12-01  13.996221  13.996221
# 23 2019-01-01  14.904529  14.904529
# 24 2019-02-01  17.573204  17.573204
# 25 2019-03-01  16.163924  16.163924
# 26 2019-04-01  17.089142  17.089142
# 27 2019-05-01  15.520809  15.520809
# 28 2019-06-01  14.966003  14.966003
# 29 2019-07-01   8.895472   8.895472
# 30 2019-08-01  13.525374  13.525374
# 31 2019-09-01  15.540745  15.540745
# 32 2019-10-01  17.982617  17.982617
# 33 2019-11-01  17.159048  17.159048
# 34 2019-12-01  16.039209  16.039209
# 35 2019-12-31  16.562860  16.562860
# 36 2020-01-31  20.853112  20.853112
# 37 2020-02-29  18.573650  18.573650
# 38 2020-03-31  19.293935  19.293935
# 39 2020-04-30  17.703131  19.473445
# 40 2020-05-31  17.093197  18.802517
# 41 2020-06-30  10.801352  11.881487
# 42 2020-07-31  15.416849  16.958534
# 43 2020-08-31  19.084584  20.993043
# 44 2020-09-30  19.689553  21.658508
# 45 2020-10-31  19.152032  21.067235
# 46 2020-11-30  18.086575  19.895232

# %%
foodfcst.rename(columns = {'adjfcst':'y'},inplace=True)
foodfcst.drop(['yhat'],axis=1, inplace=True)

# %%
f = Prophet()
f.fit(foodfcst)
future = f.make_future_dataframe(periods=12, freq='M')
forecast = f.predict(future)
fig = f.plot_components(forecast)
fig = f.plot(forecast)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
metric_df = forecast.set_index('ds')[['yhat']].join(foodfcst.set_index('ds').y).reset_index()

metric_df.dropna(inplace=True)

r2_score(metric_df.y, metric_df.yhat)
# Out:
# 0.9984214357092184

# %% [markdown]
# ## Drink

# %%
dfdrfcst= dfdrfcst[['ds','yhat']]

# %%
start=dfdrfcst[(dfdrfcst['ds']>"2020-04-01") & (dfdrfcst['ds']<"2020-12-01")]
adj=dfdrfcst[(dfdrfcst['ds']<"2020-04-01") & (dfdrfcst['ds']>="2017-01-01")]

# %%
# We model a 5% increase in drink sales beginning in April

for d in start.ds:
    start['adjfcst']=(start['yhat']*1.05)
for x in adj.ds:
    adj['adjfcst']=(adj['yhat'])
# Out:
# /Users/joesanpietro/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/joesanpietro/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
drinkfcst=pd.concat([start, adj])

drinkfcst.sort_values(by='ds').head()
# Out:
#           ds      yhat   adjfcst
# 0 2017-02-01  0.995021  0.995021
# 1 2017-03-01  2.254960  2.254960
# 2 2017-04-01  3.759600  3.759600
# 3 2017-05-01  5.677613  5.677613
# 4 2017-06-01  4.168510  4.168510

# %%
drinkfcst.rename(columns = {'adjfcst':'y'},inplace=True)
drinkfcst.drop(['yhat'],axis=1, inplace=True)
drinkfcst.head()
# Out:
#            ds          y
# 35 2020-04-30   9.137471
# 36 2020-05-31  12.268119
# 37 2020-06-30   6.299255
# 38 2020-07-31  10.455893
# 39 2020-08-31   4.512429

# %%
dr = Prophet()
dr.fit(drinkfcst)
future = dr.make_future_dataframe(periods=12, freq='M')
forecast = dr.predict(future)
fig = dr.plot_components(forecast)
fig = dr.plot(forecast)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
metric_df = forecast.set_index('ds')[['yhat']].join(drinkfcst.set_index('ds').y).reset_index()

metric_df.dropna(inplace=True)

r2_score(metric_df.y, metric_df.yhat)
# Out:
# 0.9999895513716178

# %% [markdown]
# ## Dessert

# %%
dfdesfcst= dfdesfcst[['ds','yhat']]

# %%
start=dfdesfcst[(dfdrfcst['ds']>"2020-04-01") & (dfdesfcst['ds']<"2020-12-01")]
adj=dfdesfcst[(dfdesfcst['ds']<"2020-04-01") & (dfdesfcst['ds']>="2017-01-01")]
# Out:
# /Users/joesanpietro/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
start.head()
# Out:
#            ds       yhat
# 35 2020-06-30 -44.666896
# 36 2020-07-31   3.049961
# 37 2020-08-31   6.070584
# 38 2020-09-30   5.852426
# 39 2020-10-31   7.522517

# %%
# We model a 5% decline in dessert sales beginning in April

for d in start.ds:
    start['adjfcst']=(start['yhat']-(start['yhat']*.05))
for x in adj.ds:
    adj['adjfcst']=(adj['yhat'])
# Out:
# /Users/joesanpietro/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /Users/joesanpietro/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
dessertfcst=pd.concat([start, adj])

# %%
dessertfcst.rename(columns = {'adjfcst':'y'},inplace=True)
dessertfcst.drop(['yhat'],axis=1, inplace=True)
dessertfcst.tail()
# Out:
#            ds         y
# 28 2019-12-01  4.007697
# 29 2019-12-31  1.986836
# 30 2020-01-31  2.586710
# 31 2020-02-29  6.992462
# 32 2020-03-31  8.936678

# %%
des = Prophet()
des.fit(dessertfcst)
future = des.make_future_dataframe(periods=12, freq='M')
forecast = des.predict(future)
fig = des.plot_components(forecast)
fig = des.plot(forecast)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
forecast=forecast[forecast['yhat']>0]

# %%
metric_df = forecast.set_index('ds')[['yhat']].join(dessertfcst.set_index('ds').y).reset_index()

# %%
metric_df.dropna(inplace=True)

# %%
r2_score(metric_df.y, metric_df.yhat)
# Out:
# 1.0

# %% [markdown]
# ### Clearly these models were overfitted but could be adjusted using a number of tactics,
# ### including better seasonality adjustments and other hyperparameter tuning as well as better feature engineering
